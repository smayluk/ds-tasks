# %%
import pandas as pd
data = pd.read_csv('teams_stats.csv')
data.groupby('Year').tail()
# Out:
#        Unnamed: 0    Year             Player  Pos   Age   Tm     G    GS  \
# 307           307  1950.0      Bobby Wanzer*    G  28.0  ROC  67.0   NaN
# 308           308  1950.0        Murray Wier    G  23.0  TRI  56.0   NaN
# 309           309  1950.0       D.C. Wilcutt    G  26.0  STB  37.0   NaN
# 310           310  1950.0           Bob Wood    G  28.0  SHE   6.0   NaN
# 311           311  1950.0      Max Zaslofsky   SG  24.0  CHS  68.0   NaN
# 482           482  1951.0       Brady Walker   PF  29.0  BOS  17.0   NaN
# 483           483  1951.0       Brady Walker   PF  29.0  BLB  49.0   NaN
# 484           484  1951.0       Paul Walther   SG  23.0  INO  63.0   NaN
# 485           485  1951.0      Bobby Wanzer*    G  29.0  ROC  68.0   NaN
# 486           486  1951.0      Max Zaslofsky   SG  25.0  NYK  66.0   NaN
# 613           613  1952.0       Brady Walker   PF  30.0  BLB  35.0   NaN
# 614           614  1952.0       Paul Walther   SG  24.0  INO  55.0   NaN
# ...
