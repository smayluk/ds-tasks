# %% [markdown]
# Для второго примера будем использовать следующие данные:
# Quarterly production of raw steel in Australia: thousand tonnes. Mar 1956 – Sep 1992

# %% [markdown]
# https://datamarket.com/data/set/22w4/quarterly-production-of-raw-steel-in-australia-thousand-tonnes-mar-1956-sep-1992#!ds=22w4&display=line

# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.stattools import adfuller
import statsmodels.api as sm
import statsmodels.tsa.api as smt
from statsmodels.tsa.stattools import adfuller
import matplotlib.pyplot as plt
from scipy.stats import boxcox
# %matplotlib inline
# Out:
# /anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
def test_stationarity(timeseries):
    print('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic', 'p-value', '#Lags Used', 'Number of Observations Used'])
    for [key, value] in dftest[4].items():
        dfoutput['Critical Value (%s)' % key] = value
    print(dfoutput)

# %%
def tsplot(y, lags=None, figsize=(14, 8), style='bmh'):
    test_stationarity(y)
    if not isinstance(y, pd.Series):
        y = pd.Series(y)
    with plt.style.context(style):
        plt.figure(figsize=figsize)
        layout = (4, 1)
        ts_ax = plt.subplot2grid(layout, (0, 0), rowspan=2)
        acf_ax = plt.subplot2grid(layout, (2, 0))
        pacf_ax = plt.subplot2grid(layout, (3, 0))

        y.plot(ax=ts_ax, color='blue', label='Or')
        ts_ax.set_title('Original')

        smt.graphics.plot_acf(y, lags=lags, ax=acf_ax, alpha=0.05)
        smt.graphics.plot_pacf(y, lags=lags, ax=pacf_ax, alpha=0.05)

        plt.tight_layout()
    return

# %%
df = pd.read_csv('data/quarterly-production-of-raw-stee.csv')

# %%
df.tail(2)
# Out:
#                                                Quarter  \
# 146                                             1992Q3
# 147  Quarterly production of raw steel in Australia...
#
#      Quarterly production of raw steel in Australia: thousand tonnes. Mar 1956 ? Sep 1992
# 146                                             1659.0
# 147                                                NaN

# %% [markdown]
# Уберем последнюю запись в таблице и сохраним данные в массив

# %%
series = df['Quarterly production of raw steel in Australia: thousand tonnes. Mar 1956 ? Sep 1992'][:-1].as_matrix()

# %%
series
# Out:
# array([ 590.8,  619.3,  657.4,  712.3,  743.2,  736.5,  792.4,  756.4,
#         763.7,  789.7,  816.4,  813.1,  800.6,  861.1,  870.5,  917.4,
#         871.6,  929.7,  969.3,  982.4,  879.9, 1002.5, 1048.6, 1016. ,
#        1011.8, 1059.6, 1068.7, 1097. , 1071.4, 1117.4, 1245.7, 1218.9,
#        1240. , 1197.5, 1333.3, 1276.6, 1250.2, 1259.7, 1473.1, 1476. ,
#        1338.8, 1427. , 1517.3, 1606.7, 1506. , 1563.7, 1625.8, 1569.9,
#        1571.8, 1606.4, 1606.6, 1716.5, 1731.5, 1709.3, 1758.1, 1817.6,
#        1600.8, 1701.6, 1755.5, 1763.5, 1624.1, 1650.7, 1777.7, 1684.1,
#        1520.1, 1525.7, 1785.4, 1902.2, 1785.6, 1746.9, 2058.8, 2091.1,
#        2005.4, 1593.3, 1929.9, 2226.3, 2030.3, 1876.5, 2023.4, 1913.3,
#        1961.3, 2039.2, 1960.2, 1813.2, 1809. , 1890.7, 1823.2, 1789.8,
#        1946.5, 1973.1, 1770.5, 1898.5, 1897.9, 1973.8, 2096.3, 2157.2,
#        2048.9, 1592.7, 2034.5, 1916.8, 2053.3, 1947.3, 1992.6, 1641. ,
# ...

# %% [markdown]
# Посмотрим на наш временной ряд:

# %%
tsplot(series)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -2.265625
# p-value                          0.183294
# #Lags Used                       4.000000
# Number of Observations Used    142.000000
# Critical Value (1%)             -3.477262
# Critical Value (5%)             -2.882118
# Critical Value (10%)            -2.577743
# dtype: float64

# %% [markdown]
# Как мы видим, и тест Дики-Фуллера и графики коррелограмм не отвергают гипотезу о нестационарности ряда. Для начала уберем изменение дисперсии при помощи преобразования Бокса-Кокса

# %%
series = boxcox(series, 0)

# %%
tsplot(series)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -2.791123
# p-value                          0.059553
# #Lags Used                       4.000000
# Number of Observations Used    142.000000
# Critical Value (1%)             -3.477262
# Critical Value (5%)             -2.882118
# Critical Value (10%)            -2.577743
# dtype: float64

# %% [markdown]
# Наш ряд уже близок к стационарному. Но все таки произведем дифференцирование.

# %%
series = series[1:] - series[:-1]

# %%
tsplot(series)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -6.391651e+00
# p-value                        2.098730e-08
# #Lags Used                     1.100000e+01
# Number of Observations Used    1.330000e+02
# Critical Value (1%)           -3.480500e+00
# Critical Value (5%)           -2.883528e+00
# Critical Value (10%)          -2.578496e+00
# dtype: float64

# %% [markdown]
# Теперь тест Дики-Фуллера и графики коррелограмм отвергают гипотезу о нестационарности ряда!
