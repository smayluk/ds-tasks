# %% [markdown]
# # Кластеризация. Домашнее задание

# %% [markdown]
# ### Данные
#
# В предложенных файлах информация с публичных слушаний Москвы по правилам землепользования и застройки (ПЗЗ). В них комментарии жителей города были застенагрофированы, проклассифицированы (за/против) и нанесены на карту. Данные предоставлены в 2 вариантах, для задания можно использовать любой:
# * geo_comment.xlsx
#     * **comment** - комментарий одного или списка жителей к проект
#     * **multiplier** - количество авторов комментария (может быть 1, может быть список)
#     * **x, y** - координаты адреса, по которому был дан определённой комментарий
#     * **comment_class** - за (1) / против (-1)
# * geo.xlsx - те же данные, но без текстов комментариев и по 1 голосу на строку (ранее в 1 строке могло быть **multiplier** > 1 голоса)
#     * **x, y** - координаты адреса, по которому был дан определённой комментарий
#     * **comment_class** - за (1) / против (-1)
#
# ### Обязательное задание
#
# * визуально разделить город на районы безотносительно голосов (провести кластеризацию и вывести картинку)
# * аналогично исследовать скопления голосов за и против отдельно
# * *подобрать оптимальное число кластеров при помощи кода из тетрадки в конце занятия (оптимально)*
# * приложить ноутбук
#
# ### Дополнительные задания
# * найти наиболее активные в голосовании районы *(подсказка: DBSCAN, не плотные районы обозначены одной меткой и закрашены одним цветом, cmap='gray')*
# * для тех, кто уже попробовал работу с текстом: выделить основные тематики комментариев жителей, можно использовать всю имеющуюся дополнительную информацию

# %% [markdown]
# ### Подключаем библиотеки

# %%
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

# %config InlineBackend.figure_format = 'retina'
from pylab import rcParams
rcParams['figure.figsize'] = (12, 9)

# %% [markdown]
# ### Считываем исходные данные

# %%
geo_data = pd.read_excel('geo.xlsx')

# %%
geo_comment_data = pd.read_excel('geo_comment.xlsx')

# %%
geo_data.head(5)
# Out:
#            x          y  comment_class
# 0  37.612416  55.777454             -1
# 1  37.612416  55.777454             -1
# 2  37.603298  55.742108             -1
# 3  37.558526  55.728758             -1
# 4  37.566431  55.731794             -1

# %%
geo_data.comment_class.value_counts()
# Out:
# -1    95147
#  1    13659
# Name: comment_class, dtype: int64

# %%
geo_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 108806 entries, 0 to 108805
# Data columns (total 3 columns):
# x                108806 non-null float64
# y                108806 non-null float64
# comment_class    108806 non-null int64
# dtypes: float64(2), int64(1)
# memory usage: 3.3 MB

# %%
geo_comment_data.head(5)
# Out:
#            x          y  comment_class  multiplier  \
# 0  37.612416  55.777454             -1           1
# 1  37.612416  55.777454             -1           1
# 2  37.603298  55.742108             -1           1
# 3  37.558526  55.728758             -1           1
# 4  37.566431  55.731794             -1           1
#
#                                              comment
# 0  Во все разделы правил землепользования и застр...
# 1  На основании вступившего в законную силу судеб...
# 2  Внести в Проект правил землепользования и заст...
# 3  Учитывая социальную значимость проекта строите...
# 4  Учитывая социальную значимость проекта строите...

# %%
geo_comment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 70382 entries, 0 to 70381
# Data columns (total 5 columns):
# x                70382 non-null float64
# y                70382 non-null float64
# comment_class    70382 non-null int64
# multiplier       70382 non-null int64
# comment          70382 non-null object
# dtypes: float64(2), int64(2), object(1)
# memory usage: 3.2+ MB

# %% [markdown]
# ### Посмотрим распределение голосов за/против на карте

# %%
plt.scatter(geo_data.x, geo_data.y, c=geo_data.comment_class, cmap='autumn', s=60)

# %% [markdown]
# ### Создадим выборку из координат и удалим дубликаты

# %%
X = geo_data.copy()
X = X.drop_duplicates(subset=['x', 'y']).copy()

#Голосовавшие за
X_yes = X[X.comment_class == 1].copy()
X_yes.drop("comment_class", axis=1, inplace=True)

#Голосовавшие против
X_no = X[X.comment_class == -1].copy()
X_no.drop("comment_class", axis=1, inplace=True)

X.drop("comment_class", axis=1, inplace=True)
#X : pd.DataFrame

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Сделаем кластеризацию с помощью различных методов

# %%
from sklearn.cluster import KMeans, AgglomerativeClustering, DBSCAN, AffinityPropagation
from sklearn.metrics import adjusted_rand_score, silhouette_score

# %%
claster_num = 10

# %%
algorithms = [
    AffinityPropagation(),
    KMeans(n_clusters=claster_num),
    AgglomerativeClustering(n_clusters=claster_num),
    DBSCAN(),
]

# %%
fig, axes = plt.subplots(1, len(algorithms) , figsize=(15, 4))

for ax, algorithm in zip(axes, algorithms):
    # кластеризуем и выводим картинку
    cluster = algorithm.fit_predict(X)
    ax.scatter(X.x, X.y, c=cluster, cmap='autumn', s=60)
    ax.set_title(algorithm.__class__.__name__)
  
    # если есть центры кластеров - выведем их
    if algorithm.__class__.__name__ in {'KMeans', 'AffinityPropagation'}:
        centers = algorithm.cluster_centers_
        ax.scatter(centers[:, 0], centers[:, 1], s=50)

# %% [markdown]
# Лучше всего отработали алгоритмы AgglomerativeClustering и KMeans.
# Исследуем скопления голосов за и против отдельно на примере алгоритма AgglomerativeClustering

# %% [markdown]
# ### Голосовавшие "за"

# %%
clf = AgglomerativeClustering(claster_num)
cluster = clf.fit_predict(X_yes)
plt.clf()
plt.scatter(X_yes.x, X_yes.y, c=cluster, cmap='autumn', s=60)
plt.show()

# %% [markdown]
# ### Голосовавшие "против"

# %%
clf = AgglomerativeClustering(claster_num)
cluster = clf.fit_predict(X_no)
plt.clf()
plt.scatter(X_no.x, X_no.y, c=cluster, cmap='autumn', s=60)
plt.show()

# %% [markdown]
# ### Найдем оптимальное количество кластеров для KMeans

# %%
k_inertia = []
ks = range(1,20)

for k in ks:
    clf_kmeans = KMeans(n_clusters=k)
    clusters_kmeans = clf_kmeans.fit_predict(X, )
    k_inertia.append(clf_kmeans.inertia_)

# %%
plt.plot(ks, k_inertia)

# %%
diff = np.diff(k_inertia)

# %%
plt.plot(ks[1:], diff)

# %%
diff_r = diff[1:] / diff[:-1]

# %%
plt.plot(ks[1:-1], diff_r)

# %%
k_opt = ks[np.argmin(diff_r)+1]
k_opt
# Out:
# 2
